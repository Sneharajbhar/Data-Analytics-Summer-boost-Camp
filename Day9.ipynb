# %%
# seaborn higher version of matplotlib  or have advance version graph 
# boxplot
# cluster
# stack bar chart
# error bar plot
# next leaning

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# ci class interval
# Sample dataset (like 'tips')
data = {
    'total_bill':[10,20,30,40,50,15,25,35,45,55],
    'tip':[1,2,3,4,5,1.5,2.5,3.5,4.5,5.5],
    "sex":['Male','Female']*5,
    "smoker":['Yes','No']*5,
    "day":['Thur','Fri','Sat','Sun','Thur','Fri','Sat','Sun','Tue','Mon'],
    "time":['Lunch','Dinner']*5,
    "size":[1,2,3,4,1,2,3,4,2,3]
}
df = pd.DataFrame(data)

# Set Style 
sns.set(style="whitegrid")

# %%
sns.boxplot(x='total_bill', data=df)
plt.title("Boxplot")
plt.show()

# %%
# 1 Barplot
sns.barplot(x="day",y="total_bill",data=df)
plt.title("BarPlot")
plt.show()

# %%
# 2. count plot
sns.countplot(x="day",data=df)
plt.title("Count Plot")
plt.show()

# %%
# 3. Strip Plot
sns.stripplot(x="day",y="total_bill",data=df)
plt.title("Strip Plot")
plt.show()

# %%
# 4. Violin Plot
sns.violinplot(x="day",y="total_bill",data=df)
plt.title("Violin Plot")
plt.show()

# %%
# striptplot advance version of sactter plot
# 5. Stripplot
sns.stripplot(x="day",y="total_bill",data=df)
plt.title("Stript plot")
plt.show()

# %%
# swarmplot length kam ho jayega so space kam hoga 
# 6.Swarmplot
sns.swarmplot(x="day",y="total_bill",data=df)
plt.title("Swarmp plot")
plt.show()

# %%
# 7 Pointplot
sns.pointplot(x="day",y="total_bill",data=df)
plt.title("Stript plot")
plt.show()

# %%
# 8. boxenplot
# upgrade version of boxplot
# use to distribution for large dataset
# ratio affect in boxplot
# boxplot data divide

# %%
# 8. boxenplot
sns.boxenplot(x="day",y="total_bill",data=df)
plt.title("boxen plot")
plt.show()

# %%
# KDE PLOT FOR CURVE 
# IN CIRCLE FORMAT
# HYPERBOLE AND PARABOLA 
# 9. boxenplot
sns.kdeplot(x="size",y="total_bill",data=df)
plt.title("KDE plot")
plt.show()

# %%
import pandas as pd
df = pd._csv("sample.csv")
df.head()
# Out:
# Head:first 5 rows
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,1]
plt.plot(x,y,color = 'Blue',linestyle='--',marker='o')
plt.title("line plot example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
import numpy as np
twoD = np.array([10, 20, 30])
print(np.mean(twoD))
# Out:
# 20.0

# %%
import pandas as pd
df = pd.read_csv('sample.csv')
df.dropna(inplace=True)
df.dropna()
print(df)
# Out:
#       brand                                  model  top_speed_kmh  \
# 0    Abarth                       500e Convertible            155
# 1    Abarth                         500e Hatchback            155
# 2    Abarth                    600e Scorpionissima            200
# 3    Abarth                           600e Turismo            200
# 6      Alfa          Romeo Junior Elettrica 54 kWh            150
# ..      ...                                    ...            ...
# 456   Volvo              EX90 Twin Motor (MY24-26)            180
# 457   Volvo  EX90 Twin Motor Performance (MY24-26)            180
# 468   Zeekr                     001 Long Range RWD            200
# 469   Zeekr                    001 Performance AWD            200
# 470   Zeekr                      001 Privilege AWD            200
#
#      battery_capacity_kWh battery_type  number_of_cells  torque_nm  \
# 0                    37.8  Lithium-ion            192.0      235.0
# ...

# %%
def sort(list):
    n = len(list)
    for i in range(n):
        for j in range(0, n - i - 1):
            if list[j] > list[j + 1]:
                list[j], list[j + 1] = list[j + 1], list[j]
list = [5,4,3,2,1]
sort(list)
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np
print(np.eye(3,3))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import pandas as pd
df = pd.read_csv("sample.csv")
df.fillna(0, inplace=True)
print(df)
# Out:
#        brand                    model  top_speed_kmh  battery_capacity_kWh  \
# 0     Abarth         500e Convertible            155                  37.8
# 1     Abarth           500e Hatchback            155                  37.8
# 2     Abarth      600e Scorpionissima            200                  50.8
# 3     Abarth             600e Turismo            200                  50.8
# 4     Aiways                       U5            150                  60.0
# ..       ...                      ...            ...                   ...
# 473    Zeekr           7X Premium RWD            210                  71.0
# 474    Zeekr        X Core RWD (MY25)            190                  49.0
# 475    Zeekr  X Long Range RWD (MY25)            190                  65.0
# 476    Zeekr   X Privilege AWD (MY25)            190                  65.0
# 477  firefly                        0            150                  41.2
#
# ...
